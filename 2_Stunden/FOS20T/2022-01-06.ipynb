# %%
# Begrüßung

print('Hallo Yannic')
print('Hallo Pierre')
print('Hallo Christopher')
print('Hallo Kent')
# Out:
# Hallo Yannic
# Hallo Pierre
# Hallo Christopher
# Hallo Kent

# %%
def print_Hallo(vorname):
    print('Hallo ' + vorname) # Abstand 4 Leerzeichen

print_Hallo('Yannic')
print_Hallo('Jonas')
print_Hallo('Kent')
print_Hallo('Anna')
print_Hallo('Christopher')
print_Hallo('Nils')
# Out:
# Hallo Yannic
# Hallo Jonas
# Hallo Kent
# Hallo Anna
# Hallo Christopher
# Hallo Nils

# %%
# Zählschleifen / for
for i in range(10): # Schleife von 0 bis 9
    print(3*i)
# Out:
# 0
# 3
# 6
# 9
# 12
# 15
# 18
# 21
# 24
# 27

# %%
# Bilden Sie folgende Summe 0 + 1 + 2 + 3 + 4 + .. + 1000
lsg = 500500

summe= 0 # Setzt die Variable auf 0
for summand in range(1000+1): # Schleife von 0 bis 9
    summe = summe + summand # Summiert den aktuellen Summanden auf
    
print(summe)
# Out:
# 500500

# %%
# Erstellen Sie eine Funktion f(n) = 1 + 2 + ... + n

def print_summenformel(n):
    summe= 0 # Setzt die Variable auf 0
    for summand in range(n+1): # Schleife von 0 bis 9
        summe = summe + summand # Summiert den aktuellen Summanden auf
    # print(summe)
    
print_summenformel(1000)
print_summenformel(10000)
print_summenformel(10)
print_summenformel(1)

# %%
# %timeit print_summenformel(100000)
# Out:
# 7.19 ms ± 773 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# Gaußsche Summenformel
n = 10000000000000000000000000000000000000000000000000
# %timeit (n **2 + n)/2
# Out:
# 576 ns ± 24.1 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)
